# %% [markdown]
# <a href="https://colab.research.google.com/github/maryam334/lastWork/blob/main/assignmentapplied.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit==1.14.0
# !pip install streamlit-option-menu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: streamlit==1.14.0 in /usr/local/lib/python3.8/dist-packages (1.14.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (6.0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (1.21.6)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (1.3.5)
# Requirement already satisfied: semver in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (2.13.0)
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (4.4.0)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (4.2.0)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (12.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (7.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (2.8.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (1.5.1)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (0.20.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (0.8.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (3.19.6)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (2.2.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (5.1.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (1.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (5.2.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (1.5)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (21.3)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (9.0.0)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.8/dist-packages (from streamlit==1.14.0) (3.1.29)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.14.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.14.0) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.14.0) (2.11.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit==1.14.0) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.19->streamlit==1.14.0) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.14.0) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit==1.14.0) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0) (5.10.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0) (0.19.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=14.1->streamlit==1.14.0) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.21.0->streamlit==1.14.0) (2022.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit==1.14.0) (2.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->streamlit==1.14.0) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit==1.14.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit==1.14.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit==1.14.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit==1.14.0) (1.24.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit==1.14.0) (2.6.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit==1.14.0) (0.9.1)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators>=0.2->streamlit==1.14.0) (4.4.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: streamlit-option-menu in /usr/local/lib/python3.8/dist-packages (0.3.2)
# Requirement already satisfied: streamlit>=0.63 in /usr/local/lib/python3.8/dist-packages (from streamlit-option-menu) (1.14.0)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (1.3.5)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (0.8.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (1.21.6)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (2.2.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (4.4.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (5.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (2.8.2)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (0.20.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (1.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (7.1.2)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (1.5.1)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (4.2.0)
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (2.23.0)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (21.3)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (12.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (5.2.0)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (3.1.29)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (9.0.0)
# Requirement already satisfied: semver in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (2.13.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.63->streamlit-option-menu) (6.0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (2.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-option-menu) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-option-menu) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-option-menu) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (5.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=14.1->streamlit>=0.63->streamlit-option-menu) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-option-menu) (2022.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (2.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->streamlit>=0.63->streamlit-option-menu) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (2022.12.7)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-option-menu) (2.6.1)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators>=0.2->streamlit>=0.63->streamlit-option-menu) (4.4.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: streamlit-aggrid in /usr/local/lib/python3.8/dist-packages (0.3.3)
# Requirement already satisfied: streamlit>=0.87.0 in /usr/local/lib/python3.8/dist-packages (from streamlit-aggrid) (1.14.0)
# Requirement already satisfied: python-decouple<4.0,>=3.6 in /usr/local/lib/python3.8/dist-packages (from streamlit-aggrid) (3.6)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.8/dist-packages (from streamlit-aggrid) (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2->streamlit-aggrid) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2->streamlit-aggrid) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2->streamlit-aggrid) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2->streamlit-aggrid) (1.15.0)
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (2.23.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (6.0.4)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (5.2.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (5.1.0)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (1.0.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (7.1.2)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (4.2.0)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (0.20.0)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (2.2.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (1.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (7.1.2)
# Requirement already satisfied: gitpython!=3.1.19 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (3.1.29)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (1.5)
# Requirement already satisfied: semver in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (2.13.0)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (21.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (0.8.0)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (9.0.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (4.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (0.10.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (12.6.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.8/dist-packages (from streamlit>=0.87.0->streamlit-aggrid) (3.19.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from gitpython!=3.1.19->streamlit>=0.87.0->streamlit-aggrid) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.87.0->streamlit-aggrid) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit>=0.87.0->streamlit-aggrid) (3.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (5.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=14.1->streamlit>=0.87.0->streamlit-aggrid) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit>=0.87.0->streamlit-aggrid) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.87.0->streamlit-aggrid) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.87.0->streamlit-aggrid) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.87.0->streamlit-aggrid) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.4->streamlit>=0.87.0->streamlit-aggrid) (2022.12.7)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit>=0.87.0->streamlit-aggrid) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit>=0.87.0->streamlit-aggrid) (2.6.1)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators>=0.2->streamlit>=0.87.0->streamlit-aggrid) (4.4.2)

# %%
import streamlit as st
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from streamlit_option_menu import option_menu
import streamlit.components.v1 as html
from  PIL import Image
import numpy as np
import plotly.express as px
import time

# %%
import streamlit as st
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
from streamlit_option_menu import option_menu
import streamlit.components.v1 as html
from  PIL import Image
import numpy as np
from st_aggrid import AgGrid
import plotly.express as px

online = pd.read_csv('onlinefraudMin.csv')
with st.sidebar:
    choose = option_menu("Online Fraud Payment", ["Home", "Controls1","Controls2", "Data View","Contact Us"],
                         icons=['house', 'gear', 'gear', 'list','phone'],
                         menu_icon="app-indicator", default_index=0,
                         styles={
        "container": {"padding": "5!important", "background-color": "#fafafa"},
        "icon": {"color": "green", "font-size": "25px"}, 
        "nav-link": {"font-size": "16px", "text-align": "left", "margin":"0px", "--hover-color": "#A3BFF2"},
        "nav-link-selected": {"background-color": "#56E0F6"},
    }
    )

if choose == "Home":
             
              col1, col2 = st.columns( [0.9, 0.1])
              with col1:              
                  st.markdown(""" <style> .font {
                  font-size:35px ; font-family: 'Cooper Black'; color: #FF9633;} 
                  </style> """, unsafe_allow_html=True)
                  st.markdown('<p class="font">About the App</p>', unsafe_allow_html=True)    
              with col2:              
                  st.write("")
                        
              st.write("A dataset is a collection of information concerning online payment")
              st.write("fraud that enables us to identify the transactions that are most likely to result in fraud.")
              st.write("In order to identify fraud in online payments, we will present historical data regarding fraudulent transactions.")
              st.write("We obtained the dataset for this work from Kaggle.com and made necessary modifications to it.")

              col1, col2 = st.columns( [0.9, 0.1])
              with col1:              
                  st.markdown(""" <style> .font {
                  font-size:35px ; font-family: 'Cooper Black'; color: #803C04;} 
                  </style> """, unsafe_allow_html=True)
                  st.markdown('<p class="font">Findings</p>', unsafe_allow_html=True)    
              with col2:              
                  st.write("")
                        
              st.write("Payment: According to the findings, the majority of the Old Balance organization spent less than $40,000 in payments.")
              st.write("Transfer: As the chart shows, the amount transferred has skyrocketed in the old balance organization. ")
              st.write("Cash_out: The chart depicts cash out, which has reached a nadir in the old balance organization.")
              st.write("Debit: In the old balance organization, the chart depicts the highest amount in debit of less than 45,000.")
              st.write("Cash_in: The chart shows that the majority of the cash in the old balance organization was less than $1,000,000.") 


elif choose == "Data View":
      
      st.markdown(""" <style> .font {
          font-size:35px ; font-family: 'Cooper Black'; color: #FF9633;} 
          </style> """, unsafe_allow_html=True)
      st.markdown('<p class="font">View Your Data</p>', unsafe_allow_html=True)
      
      df = pd.DataFrame(online)
      @st.cache
      def convert_df(df):
          return df.to_csv().encode('utf-8')

      csv = convert_df(df)

      st.download_button(
          label="Download data as CSV",
          data=csv,
          file_name='download.csv',
          mime='text/csv',
      )
      st.dataframe(df)
      

elif choose == "Controls1":
      st.markdown(""" <style> .font {
          font-size:35px ; font-family: 'Cooper Black'; color: #FF9633;} 
          </style> """, unsafe_allow_html=True)
      st.markdown('<p class="font">Work with Controls</p>', unsafe_allow_html=True)
      new = st.selectbox("Select Pyment type", online['type'].unique())

      plot_type = st.radio("select the plot type", ['scatter', 'bar','area'])
      if plot_type == 'scatter':

          pl = alt.Chart(online[online['type'] == new]).mark_circle().encode(
              x='oldbalanceOrg',
              y='amount',
              tooltip=['oldbalanceOrg', 'amount']
          ).interactive()
          st.altair_chart(pl)
      elif plot_type == 'bar':
          pl = alt.Chart(online[online['type'] == new]).mark_bar().encode(
              x='oldbalanceOrg',
              y='amount',
              tooltip=['oldbalanceOrg', 'amount']
          ).interactive()
          st.altair_chart(pl)
      elif plot_type == 'area':
           pl = alt.Chart(online[online['type'] == new]).mark_area().encode(
              x='oldbalanceOrg',
              y='amount',
              tooltip=['oldbalanceOrg', 'amount']
           ).interactive()
           st.altair_chart(pl)
elif choose == "Controls2":
     
           
      st.markdown(""" <style> .font {
          font-size:35px ; font-family: 'Cooper Black'; color: #FF9633;} 
          </style> """, unsafe_allow_html=True)
      st.markdown('<p class="font">Work with Controls</p>', unsafe_allow_html=True)
      new =st.multiselect('Type Of Payment',online['type'].unique())
      if len(new) > 0:
          plot_type = st.radio("select the plot type", ['line','rect'])
          if plot_type == 'line':
              pl = alt.Chart(online[online['type'] == new[0]]).mark_line().encode(
                  x='oldbalanceOrg',
                  y='amount',
                  tooltip=['oldbalanceOrg', 'amount']
              ).interactive()
              st.altair_chart(pl)
          elif plot_type == 'rect':
              pl = alt.Chart(online[online['type'] == new[0]]).mark_rect().encode(
                  x='oldbalanceOrg',
                  y='amount',
                  tooltip=['oldbalanceOrg', 'amount']
              ).interactive()
              st.altair_chart(pl)
elif choose == "Contact Us":
      st.markdown(""" <style> .font {
      font-size:35px ; font-family: 'Cooper Black'; color: #FF9633;} 
      </style> """, unsafe_allow_html=True)
      st.markdown('<p class="font">Contact Form</p>', unsafe_allow_html=True)
      with st.form(key='columns_in_form2',clear_on_submit=True): 
                  st.write('Please Contact Us In Case Of Any Query!')
                  st.text_input(label='Please Enter Your Name') 
                  st.text_input(label='Please Enter Email') 
                  st.text_area('Please Enter Your Message')
                  st.multiselect('Subject',['Need Help', 'Data Correction', 'Feedback', 'Wrong Data'])
                  st.checkbox('I agree to send me promotional emails') 
                  submitted = st.form_submit_button('SEND')
                  if submitted:
                      st.write('Thanks for your contacting us. We will respond to your questions or inquiries as soon as possible!')

# %% [markdown]
# # New Section

# %%
# !streamlit run main.py &>/dev/null&
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.456s
# your url is: https://three-taxis-read-35-231-169-20.loca.lt
# ^C

# %% [markdown]
#  https://maryam334-lastwork-main-cmdoup.streamlit.app/

# %% [markdown]
# github username=maryam334
# https://github.com/maryam334/lastWork
